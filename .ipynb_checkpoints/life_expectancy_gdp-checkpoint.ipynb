# %%
#import required libraries
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
#load data from csv
data = pd.read_csv("all_data.csv")

# %%
#data overview
#renaming columns for ease of use
data.columns=['country', 'year', 'life_exp', 'gdp']
#making gdp more readable, putting amounts in billions
data['gdp'] = data['gdp'].map(lambda x: round(x/1000000000,2))
data = data.replace('United States of America', 'USA')
data.head()
# Out:
#   country  year  life_exp    gdp
# 0   Chile  2000      77.3  77.86
# 1   Chile  2001      77.3  70.98
# 2   Chile  2002      77.8  69.74
# 3   Chile  2003      77.9  75.64
# 4   Chile  2004      78.0  99.21

# %%
#pulling out country names for label use
countries=data.country.unique()
country_data = {}

# %%
for country in countries:
    country_title = str(country).strip().lower() #clean and prep the country name for variable usage
    country_data[country_title] = data[data['country'] == country]  # Filter and store the data
    
country_data['usa']
# Out:
#    country  year  life_exp      gdp
# 64     USA  2000      76.8  10300.0
# 65     USA  2001      76.9  10600.0
# 66     USA  2002      77.0  11000.0
# 67     USA  2003      77.2  11500.0
# 68     USA  2004      77.5  12300.0
# 69     USA  2005      77.5  13100.0
# 70     USA  2006      77.8  13900.0
# 71     USA  2007      78.1  14500.0
# 72     USA  2008      78.2  14700.0
# 73     USA  2009      78.5  14400.0
# 74     USA  2010      78.7  15000.0
# 75     USA  2011      78.7  15500.0
# 76     USA  2012      78.8  16200.0
# 77     USA  2013      78.9  16700.0
# 78     USA  2014      79.1  17400.0
# 79     USA  2015      79.3  18100.0

# %%
for key in country_data:
    
    sns.lmplot(data = country_data[key], x = 'life_exp', y ='gdp')
    
    plt.title(f"GDP vs Life Expectancy, {str(key).upper()}")
    plt.show()
    plt.clf()

# %%
avg_data = data[['country', 'life_exp', 'gdp']].groupby('country').mean().apply(lambda x: round(x,2)).reset_index()
avg_data.head()
# Out:
#                     country  life_exp       gdp
# 0                     Chile     78.94    169.79
# 1                     China     74.26   4957.71
# 2                   Germany     79.66   3094.78
# 3                    Mexico     75.72    976.65
# 4  United States of America     78.06  14075.00

# %%
sns.scatterplot(y=data.gdp, x= data.life_exp, hue = data.country, size=data.gdp, sizes=(25,250), legend=False)
plt.title('Life Expectancy vs GDP')
plt.show()
plt.clf()

# %%
#pivoting data to look at country info by year
life_pivot = data.pivot(index='country', columns='year', values='life_exp')
life_pivot.head()
# Out:
# year                      2000  2001  2002  2003  2004  2005  2006  2007  \
# country
# Chile                     77.3  77.3  77.8  77.9  78.0  78.4  78.9  78.9
# China                     71.7  72.2  72.7  73.1  73.5  73.9  74.2  74.4
# Germany                   78.0  78.3  78.4  78.5  79.1  79.2  79.6  79.8
# Mexico                    74.8  75.0  75.0  75.0  75.4  75.3  75.8  76.0
# United States of America  76.8  76.9  77.0  77.2  77.5  77.5  77.8  78.1
#
# year                      2008  2009  2010  2011  2012  2013  2014  2015
# country
# Chile                     79.6  79.3  79.1  79.8  79.9  80.1  80.3  80.5
# China                     74.5  74.9  75.0  75.2  75.4  75.6  75.8  76.1
# Germany                   79.9  80.0  80.1  80.5  80.6  80.6  80.9  81.0
# Mexico                    75.6  75.7  75.6  76.1  76.3  76.6  76.6  76.7
# United States of America  78.2  78.5  78.7  78.7  78.8  78.9  79.1  79.3

# %%
gdp_pivot = data.pivot(index='country', columns='year', values='gdp')
#gdp_pivot.reset_index(inplace=True)
gdp_pivot.head()
# Out:
# year                          2000      2001      2002      2003      2004  \
# country
# Chile                        77.86     70.98     69.74     75.64     99.21
# China                      1211.35   1339.40   1470.55   1660.29   1955.35
# Germany                    1949.95   1950.65   2079.14   2505.73   2819.25
# Mexico                      683.65    724.70    741.56    713.28    770.27
# United States of America  10300.00  10600.00  11000.00  11500.00  12300.00
#
# year                          2005      2006      2007      2008      2009  \
# country
# Chile                       122.97    154.79    173.61    179.64    172.39
# China                      2285.97   2752.13   3552.18   4598.21   5109.95
# Germany                    2861.41   3002.45   3439.95   3752.37   3418.01
# Mexico                      866.35    965.28   1043.47   1101.28    894.95
# United States of America  13100.00  13900.00  14500.00  14700.00  14400.00
#
# year                          2010      2011      2012      2013      2014  \
# country
# Chile                       218.54    252.25    267.12    278.38    260.99
# China                      6100.62   7572.55   8560.55   9607.22  10482.40
# Germany                    3417.09   3757.70   3543.98   3752.51   3890.61
# Mexico                     1051.13   1171.19   1186.60   1261.98   1298.46
# United States of America  15000.00  15500.00  16200.00  16700.00  17400.00
#
# year                          2015
# country
# Chile                       242.52
# China                     11064.70
# Germany                    3375.61
# Mexico                     1152.26
# United States of America  18100.00

# %%
year_pivot = data.pivot(index = 'year', columns = 'country', values = 'life_exp')
year_pivot.head()
# Out:
# country  Chile  China  Germany  Mexico  United States of America  Zimbabwe
# year
# 2000      77.3   71.7     78.0    74.8                      76.8      46.0
# 2001      77.3   72.2     78.3    75.0                      76.9      45.3
# 2002      77.8   72.7     78.4    75.0                      77.0      44.8
# 2003      77.9   73.1     78.5    75.0                      77.2      44.5
# 2004      78.0   73.5     79.1    75.4                      77.5      44.3

# %%
plt.figure(figsize=(10, 6))
for country in year_pivot.columns:
    plt.plot(year_pivot.index, year_pivot[country], label=country)
plt.legend()
plt.title("Life Expectancy Over the Years by Country")
plt.ylabel("Life Expectancy (Years)")
plt.xlabel("Year")
plt.show()
plt.clf()

# %%
data.head()
# Out:
#   country  year  life_exp    gdp
# 0   Chile  2000      77.3  77.86
# 1   Chile  2001      77.3  70.98
# 2   Chile  2002      77.8  69.74
# 3   Chile  2003      77.9  75.64
# 4   Chile  2004      78.0  99.21
